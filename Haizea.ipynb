# %%
import json
import xmltodict

# %%
# converts time string to seconds

def convertTime(curTime):
    curTime = curTime[:8]
    parts = curTime.split(':')
    return int(parts[0])*3600 + int(parts[1])*60 + int(parts[2])

# %%
# reading xml file and un-marshalling to python object
# converting the time to seconds
# calculating slack time

xml_file = open("data4.lwf")
data = xmltodict.parse(xml_file.read())["lease-workload"]
xml_file.close()

maxNodes = int(data["site"]["nodes"]["node-set"]["@numnodes"])
strval = ""
requests = []
for request in data["lease-requests"]["lease-request"]:
    temp = {}
    temp["id"] = request["lease"]["@id"]
    temp["arrival"] = convertTime(request["@arrival"])
    temp["nodes"] = int(request["lease"]["nodes"]["node-set"]["@numnodes"])
    temp["start"] = convertTime(request["lease"]["start"]["exact"]["@time"])
    temp["duration"] = convertTime(request["lease"]["duration"]["@time"])
    temp["deadline"] = convertTime(request["lease"]["deadline"]["@time"])
    temp["slack"] = round(
        (temp["deadline"] - temp["start"]) / temp["duration"], 2)
    requests.append(temp)

# %%
requests = sorted(requests, key=lambda d: d['arrival'])

# %%
def haizea(requests):
    temp = []
    for req in requests:
        if(req["slack"]<=1.1):
            printf("Request with ID = %d has been rejected due to slack time <=1.1", req["id"])
            continue
        else:
            temp.append(req)

# %%
def check(sch,start,end):
    for i in range(len(sch)-1):
        if(sch[i][1]<=start and end<=sch[i+1][0]):
            return True
    return False

# %%
def findSlot(req, sch):
    startTime = req["start"]
    deadline = req["deadline"]
    duration = req["duration"]
    nodes = req["nodes"]
    id=req["id"]
    found=False

    for i in range(len(sch)):
        for j in range(len(sch[i])-1):
            if(sch[i][j][1]>=startTime or startTime<=sch[i][j+1][0]):    #checkling if startime is grater than or equal to start time or less than next lease endtime  
                st=max(startTime,sch[i][j][1])                              #start time is max of start time and end time of previous end time
                if(st+duration<=sch[i][j+1][0] and st+duration<=deadline):      

                    available_nodes=[]                                  #available node for the scheduling for given start and duration

                    for x in range(len(sch)):
                        if check(sch[x],st,st+duration):                #checking the nodes for the given start and duration
                            available_nodes.append(x)
                    
                    if len(available_nodes)>=nodes: 
                        
                        tmp=[st,st+duration,id]
                        for x in range(nodes):

                            sch[available_nodes[x]].append(tmp)
                            sch[available_nodes[x]].sort()
                        found=True
                        break
        
        if found:
            return True
    return False

# %%
def reschedule(req,sc):

    dup = []
    count=0
    st=[0,0,0] 
    en=[1e9,1e9,1e9]

    for i in range(maxNodes):
        tmp=[]
        dup.append(tmp)
    nsl=[]
    st=req["start"]
    print(str(req))
    for i in range(len(sc)):
        for j in range(len(sc[i])):

            if(st<=sc[i][j][0]):
                nsl.append(sc[i][j])
            else:
                dup[i].append(sc[i][j])

    nsld=[]
    nsld.append(req)
    for i in range(len(requests)):
        for j in range(len(nsl)):

            if(requests[i]["id"]==nsl[j][2]):
                nsld.append(requests[i])
    
    print(type(nsld[0]))
    for i in range(len(nsld)):

        if not findSlot(nsld[i],dup):
            
            return sc,1
        
    return dup,0

# %%
sc = []
count=0
st=[0,0,0] 
en=[1e9,1e9,1e9]

for i in range(maxNodes):
    tmp=[st,en]
    sc.append(tmp)


for i in range(len(requests)):
    if not findSlot(requests[i],sc):
        sc,didnt=reschedule(requests[i],sc)
        count+=didnt  

print("Total Leases:", len(requests))
print("Total Leases Scheduled:", len(requests) - count)
print("Scheduled Percentage:", ((len(requests) - count)/ len(requests))*100)
print("Not possible to schedule", count)
# Out:
# {'id': '2', 'arrival': 43210, 'nodes': 2, 'start': 43800, 'duration': 7200, 'deadline': 57600, 'slack': 1.92}
# <class 'dict'>
# {'id': '6', 'arrival': 43250, 'nodes': 4, 'start': 64800, 'duration': 3600, 'deadline': 70200, 'slack': 1.5}
# <class 'dict'>
# {'id': '10', 'arrival': 43290, 'nodes': 4, 'start': 72000, 'duration': 1800, 'deadline': 77400, 'slack': 3.0}
# <class 'dict'>
# {'id': '11', 'arrival': 43300, 'nodes': 4, 'start': 79200, 'duration': 1800, 'deadline': 82800, 'slack': 2.0}
# <class 'dict'>
# {'id': '12', 'arrival': 43310, 'nodes': 4, 'start': 82800, 'duration': 1800, 'deadline': 86400, 'slack': 2.0}
# <class 'dict'>
# {'id': '17', 'arrival': 43360, 'nodes': 4, 'start': 90000, 'duration': 1800, 'deadline': 93600, 'slack': 2.0}
# <class 'dict'>
# {'id': '19', 'arrival': 43380, 'nodes': 4, 'start': 97200, 'duration': 3600, 'deadline': 108000, 'slack': 3.0}
# <class 'dict'>
# {'id': '21', 'arrival': 43400, 'nodes': 4, 'start': 108000, 'duration': 3600, 'deadline': 115200, 'slack': 2.0}
# <class 'dict'>
# {'id': '22', 'arrival': 43410, 'nodes': 2, 'start': 43800, 'duration': 1200, 'deadline': 50400, 'slack': 5.5}
# <class 'dict'>
# {'id': '23', 'arrival': 43420, 'nodes': 2, 'start': 43800, 'duration': 1200, 'deadline': 50400, 'slack': 5.5}
# <class 'dict'>
# {'id': '24', 'arrival': 43430, 'nodes': 2, 'start': 43800, 'duration': 1200, 'deadline': 50400, 'slack': 5.5}
# <class 'dict'>
# {'id': '25', 'arrival': 43440, 'nodes': 2, 'start': 43800, 'duration': 1800, 'deadline': 50400, 'slack': 3.67}
# <class 'dict'>
# {'id': '26', 'arrival': 43450, 'nodes': 4, 'start': 43800, 'duration': 3600, 'deadline': 54000, 'slack': 2.83}
# <class 'dict'>
# {'id': '27', 'arrival': 43460, 'nodes': 2, 'start': 59400, 'duration': 1800, 'deadline': 63000, 'slack': 2.0}
# <class 'dict'>
# {'id': '28', 'arrival': 43470, 'nodes': 1, 'start': 57600, 'duration': 3600, 'deadline': 63000, 'slack': 1.5}
# <class 'dict'>
# {'id': '31', 'arrival': 43500, 'nodes': 1, 'start': 68400, 'duration': 3000, 'deadline': 72000, 'slack': 1.2}
# <class 'dict'>
# {'id': '36', 'arrival': 43550, 'nodes': 1, 'start': 81000, 'duration': 3600, 'deadline': 86400, 'slack': 1.5}
# <class 'dict'>
# {'id': '38', 'arrival': 43570, 'nodes': 4, 'start': 97200, 'duration': 2400, 'deadline': 104400, 'slack': 3.0}
# <class 'dict'>
# {'id': '39', 'arrival': 43580, 'nodes': 4, 'start': 97200, 'duration': 2400, 'deadline': 104400, 'slack': 3.0}
# <class 'dict'>
# {'id': '40', 'arrival': 43590, 'nodes': 4, 'start': 97200, 'duration': 2400, 'deadline': 104400, 'slack': 3.0}
# <class 'dict'>
# Total Leases: 43
# Total Leases Scheduled: 23
# Scheduled Percentage: 53.48837209302325
# Not possible to schedule 20

# %%
sc[0]
# Out:
# [[0, 0, 0],
#  [43800, 54000, '1'],
#  [54000, 55200, '29'],
#  [57600, 60000, '2'],
#  [60000, 61800, '3'],
#  [61800, 63600, '4'],
#  [65400, 66600, '5'],
#  [66600, 68400, '6'],
#  [68400, 70800, '7'],
#  [70800, 71400, '24'],
#  [71400, 78600, '8'],
#  [82200, 83400, '9'],
#  [83400, 85800, '10'],
#  [87000, 90600, '11'],
#  [90600, 93000, '31'],
#  [93000, 95400, '12'],
#  [95400, 97800, '32'],
#  [97800, 100800, '13'],
#  [1000000000.0, 1000000000.0, 1000000000.0]]

# %%
sc[1]
# Out:
# [[0, 0, 0],
#  [43800, 54000, '1'],
#  [57600, 60000, '2'],
#  [60000, 61800, '3'],
#  [61800, 63600, '4'],
#  [63600, 66000, '23'],
#  [66600, 68400, '6'],
#  [68400, 70800, '7'],
#  [70800, 71400, '24'],
#  [71400, 78600, '8'],
#  [82200, 83400, '9'],
#  [83400, 85800, '10'],
#  [87000, 90600, '11'],
#  [90600, 93000, '31'],
#  [93000, 95400, '12'],
#  [95400, 97800, '32'],
#  [97800, 100800, '13'],
#  [1000000000.0, 1000000000.0, 1000000000.0]]

# %%
sc[2]
# Out:
# [[0, 0, 0],
#  [43800, 54000, '1'],
#  [60000, 61800, '3'],
#  [61800, 63600, '4'],
#  [63600, 66000, '23'],
#  [66600, 67200, '21'],
#  [68400, 70800, '7'],
#  [70800, 71400, '24'],
#  [71400, 78600, '8'],
#  [82200, 83400, '27'],
#  [83400, 85800, '10'],
#  [87000, 90600, '11'],
#  [93000, 95400, '12'],
#  [95400, 97800, '32'],
#  [97800, 100800, '33'],
#  [1000000000.0, 1000000000.0, 1000000000.0]]

# %%
data
# Out:
# {'@name': 'deadline10',
#  'description': 'First lease does not end prematurely.\nSecond and third lease end prematurely.\nSecond and third lease start at 00:15:00.00 and 00:20:00.00',
#  'site': {'resource-types': {'@names': 'CPU Memory'},
#   'nodes': {'node-set': {'@numnodes': '3',
#     'res': [{'@type': 'CPU', '@amount': '100'},
#      {'@type': 'Memory', '@amount': '1024'}]}}},
#  'lease-requests': {'lease-request': [{'@arrival': '12:00:00.00',
#     'lease': {'@id': '1',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '12:10:00.00'}},
#      'duration': {'@time': '02:00:00.00'},
#      'deadline': {'@time': '16:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:00:10.00',
#     'lease': {'@id': '2',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '512', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '12:10:00.00'}},
#      'duration': {'@time': '02:00:00.00'},
#      'deadline': {'@time': '16:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:00:20.00',
#     'lease': {'@id': '3',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '16:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '17:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:00:30.00',
#     'lease': {'@id': '4',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '3',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '16:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '17:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:00:40.00',
#     'lease': {'@id': '5',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '3',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '17:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '18:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:00:50.00',
#     'lease': {'@id': '6',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '4',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '18:00:00.00'}},
#      'duration': {'@time': '01:00:00.00'},
#      'deadline': {'@time': '19:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:01:00.00',
#     'lease': {'@id': '7',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '3',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '19:30:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '20:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:01:10.00',
#     'lease': {'@id': '8',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '20:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '21:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:01:20.00',
#     'lease': {'@id': '9',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '3',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '20:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '21:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:01:30.00',
#     'lease': {'@id': '10',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '4',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '20:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '21:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:01:40.00',
#     'lease': {'@id': '11',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '4',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '22:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '23:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:01:50.00',
#     'lease': {'@id': '12',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '4',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '23:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '24:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:02:00.00',
#     'lease': {'@id': '13',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '3',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '23:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '24:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:02:10.00',
#     'lease': {'@id': '14',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '24:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '25:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:02:20.00',
#     'lease': {'@id': '15',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '1',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '24:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '25:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:02:30.00',
#     'lease': {'@id': '16',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '24:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '25:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:02:40.00',
#     'lease': {'@id': '17',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '4',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '25:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '26:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:02:40.00',
#     'lease': {'@id': '18',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '25:00:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '26:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:03:00.00',
#     'lease': {'@id': '19',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '4',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '27:00:00.00'}},
#      'duration': {'@time': '01:00:00.00'},
#      'deadline': {'@time': '30:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:03:10.00',
#     'lease': {'@id': '20',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '3',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '30:00:00.00'}},
#      'duration': {'@time': '01:00:00.00'},
#      'deadline': {'@time': '32:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:03:20.00',
#     'lease': {'@id': '21',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '4',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '30:00:00.00'}},
#      'duration': {'@time': '01:00:00.00'},
#      'deadline': {'@time': '32:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:03:30.00',
#     'lease': {'@id': '22',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '12:10:00.00'}},
#      'duration': {'@time': '00:20:00.00'},
#      'deadline': {'@time': '14:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:03:40.00',
#     'lease': {'@id': '23',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '12:10:00.00'}},
#      'duration': {'@time': '00:20:00.00'},
#      'deadline': {'@time': '14:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:03:50.00',
#     'lease': {'@id': '24',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '12:10:00.00'}},
#      'duration': {'@time': '00:20:00.00'},
#      'deadline': {'@time': '14:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:04:00.00',
#     'lease': {'@id': '25',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '12:10:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '14:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:04:10.00',
#     'lease': {'@id': '26',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '4',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '12:10:00.00'}},
#      'duration': {'@time': '01:00:00.00'},
#      'deadline': {'@time': '15:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:04:20.00',
#     'lease': {'@id': '27',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '16:30:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '17:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:04:30.00',
#     'lease': {'@id': '28',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '1',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '16:00:00.00'}},
#      'duration': {'@time': '01:00:00.00'},
#      'deadline': {'@time': '17:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:04:40.00',
#     'lease': {'@id': '29',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '3',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '17:30:00.00'}},
#      'duration': {'@time': '01:00:00.00'},
#      'deadline': {'@time': '19:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:04:50.00',
#     'lease': {'@id': '30',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '1',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '17:30:00.00'}},
#      'duration': {'@time': '00:40:00.00'},
#      'deadline': {'@time': '19:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:05:00.00',
#     'lease': {'@id': '31',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '1',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '19:00:00.00'}},
#      'duration': {'@time': '00:50:00.00'},
#      'deadline': {'@time': '20:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:05:10.00',
#     'lease': {'@id': '32',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '20:30:00.00'}},
#      'duration': {'@time': '00:20:00.00'},
#      'deadline': {'@time': '21:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:05:20.00',
#     'lease': {'@id': '33',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '20:30:00.00'}},
#      'duration': {'@time': '00:10:00.00'},
#      'deadline': {'@time': '21:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:05:30.00',
#     'lease': {'@id': '34',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '1',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '20:30:00.00'}},
#      'duration': {'@time': '00:30:00.00'},
#      'deadline': {'@time': '21:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:05:40.00',
#     'lease': {'@id': '35',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '3',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '21:30:00.00'}},
#      'duration': {'@time': '01:00:00.00'},
#      'deadline': {'@time': '23:30:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:05:50.00',
#     'lease': {'@id': '36',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '1',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '22:30:00.00'}},
#      'duration': {'@time': '01:00:00.00'},
#      'deadline': {'@time': '24:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:06:00.00',
#     'lease': {'@id': '37',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '1',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '24:30:00.00'}},
#      'duration': {'@time': '01:00:00.00'},
#      'deadline': {'@time': '26:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:06:10.00',
#     'lease': {'@id': '38',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '4',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '27:00:00.00'}},
#      'duration': {'@time': '00:40:00.00'},
#      'deadline': {'@time': '29:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:06:20.00',
#     'lease': {'@id': '39',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '4',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '27:00:00.00'}},
#      'duration': {'@time': '00:40:00.00'},
#      'deadline': {'@time': '29:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:06:30.00',
#     'lease': {'@id': '40',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '4',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '27:00:00.00'}},
#      'duration': {'@time': '00:40:00.00'},
#      'deadline': {'@time': '29:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:06:40.00',
#     'lease': {'@id': '41',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '1',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '29:00:00.00'}},
#      'duration': {'@time': '02:00:00.00'},
#      'deadline': {'@time': '33:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:06:50.00',
#     'lease': {'@id': '42',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '1',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '12:10:00.00'}},
#      'duration': {'@time': '01:00:00.00'},
#      'deadline': {'@time': '21:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}},
#    {'@arrival': '12:07:00.00',
#     'lease': {'@id': '43',
#      '@preemptible': 'true',
#      'nodes': {'node-set': {'@numnodes': '2',
#        'res': [{'@amount': '100', '@type': 'CPU'},
#         {'@amount': '1024', '@type': 'Memory'}]}},
#      'start': {'exact': {'@time': '25:00:00.00'}},
#      'duration': {'@time': '01:00:00.00'},
#      'deadline': {'@time': '32:00:00.00'},
#      'software': {'disk-image': {'@id': 'foobar1.img', '@size': '1024'}}}}]}}

# %%
data['site']['nodes']['node-set']['@numnodes']
# Out:
# '4'
